# %% [markdown]
# ### Import the processed dataset from zipped file

# %%
import gzip
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

with gzip.open("Preprocessed data.gz") as f:
    df = pd.read_csv(f)

df['Country Name'] = df['Country Name'].str.strip()
df.head()
# Out:
#   Country Name Country Code  Series Code          1970          1971  \
# 0  Afghanistan          AFG  DT.GPA.DPPG  2.132790e+08  2.543125e+08
# 1  Afghanistan          AFG  DT.GPA.OFFT  2.132790e+08  2.543125e+08
# 2  Afghanistan          AFG  DT.GPA.PRVT  2.132790e+08  2.543125e+08
# 3  Afghanistan          AFG  DT.GRE.DPPG  2.132790e+08  2.543125e+08
# 4  Afghanistan          AFG  DT.GRE.OFFT  2.132790e+08  2.543125e+08
#
#            1972          1973          1974          1975          1976  ...  \
# 0  2.807850e+08  3.388542e+08  4.349602e+08  5.446476e+08  6.095969e+08  ...
# 1  2.807850e+08  3.388542e+08  4.349602e+08  5.446476e+08  6.095969e+08  ...
# 2  2.807850e+08  3.388542e+08  4.349602e+08  5.446476e+08  6.095969e+08  ...
# 3  2.807850e+08  3.388542e+08  4.349602e+08  5.446476e+08  6.095969e+08  ...
# 4  2.807850e+08  3.388542e+08  4.349602e+08  5.446476e+08  6.095969e+08  ...
#
#    2011  2012  2013     2014  2015  2016     2017  2018     2019  2020
# ...

# %%
# List of "countries" that will be dropped
to_be_dropped = ['East Asia & Pacific (excluding high income)', 'Europe & Central Asia (excluding high income)', 'IDA only',
                 'Latin America & Caribbean (excluding high income)',
                 'Least developed countries: UN classification', 'Low & middle income',
                 'Low income', 'Upper middle income', 'South Asia'
                 'Lower middle income', 'Middle East & North Africa (excluding high income)',
                 'Middle income', 'Sub-Saharan Africa (excluding high income)']
df = df[~df['Country Name'].isin(to_be_dropped)]

# %%
# Transform the top_10 list to a proper shape
filtered_df = df.groupby(by='Country Name').agg('sum').transpose() / 1e9

# %%
# https://towardsdatascience.com/creating-bar-chart-race-animation-with-python-cdb01144074e
import bar_chart_race as bcr

bcr.bar_chart_race(df=filtered_df,
                   n_bars=10,
                   sort='desc',
                   title='Debts of top 10 countries from 1970 in Billion dollars',
                   filename='top_10.mp4')
# Out:
# C:\Users\dtngh\miniconda3\lib\site-packages\bar_chart_race\_make_chart.py:284: UserWarning: Glyph 127 () missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# C:\Users\dtngh\miniconda3\lib\site-packages\bar_chart_race\_make_chart.py:284: UserWarning: Glyph 128 (\x80) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# C:\Users\dtngh\miniconda3\lib\site-packages\bar_chart_race\_make_chart.py:284: UserWarning: Glyph 129 (\x81) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# C:\Users\dtngh\miniconda3\lib\site-packages\bar_chart_race\_make_chart.py:284: UserWarning: Glyph 130 (\x82) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# C:\Users\dtngh\miniconda3\lib\site-packages\bar_chart_race\_make_chart.py:284: UserWarning: Glyph 131 (\x83) missing from current font.
#   fig.canvas.print_figure(io.BytesIO())
# ...
